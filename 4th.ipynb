# %%
import pandas as pd
movies_del = pd.read_csv('movies.csv')
movies_del.shape
movies_del.columns

movies_del1 = movies_del.drop('Rotten Tomatoes %',axis=1)
movies_del1.shape
# Out:
# (77, 7)

# %%
movies_del.drop([1,2,3,4],axis=0)#행으로.펜시검색
# Out:
#                                    Film      Genre            Lead Studio  \
# 0            Zack and Miri Make a Porno    Romance  The Weinstein Company
# 5                   Water For Elephants      Drama       20th Century Fox
# 6                                WALL-E  Animation                 Disney
# 7                              Waitress    Romance            Independent
# 8                   Waiting For Forever    Romance            Independent
# 9                       Valentine's Day     Comedy           Warner Bros.
# 10  Tyler Perry's Why Did I get Married    Romance            Independent
# 11              Twilight: Breaking Dawn    Romance            Independent
# 12                             Twilight    Romance                 Summit
# 13                       The Ugly Truth     Comedy            Independent
# 14          The Twilight Saga: New Moon      Drama                 Summit
# 15             The Time Traveler's Wife      Drama              Paramount
# ...

# %%
movies_del.shape
# Out:
# (77, 8)

# %%
a=movies_del.drop([1,2,3,4],axis=0)#행으로.펜시검색.즉 대입하지 않으면 인덱스가 앞으로 안밀려나서 위는 (77,8)인가?
a
# Out:
#                                    Film      Genre            Lead Studio  \
# 0            Zack and Miri Make a Porno    Romance  The Weinstein Company
# 5                   Water For Elephants      Drama       20th Century Fox
# 6                                WALL-E  Animation                 Disney
# 7                              Waitress    Romance            Independent
# 8                   Waiting For Forever    Romance            Independent
# 9                       Valentine's Day     Comedy           Warner Bros.
# 10  Tyler Perry's Why Did I get Married    Romance            Independent
# 11              Twilight: Breaking Dawn    Romance            Independent
# 12                             Twilight    Romance                 Summit
# 13                       The Ugly Truth     Comedy            Independent
# 14          The Twilight Saga: New Moon      Drama                 Summit
# 15             The Time Traveler's Wife      Drama              Paramount
# ...

# %%
#movies_del1 = movies_del.drop('Rotten Tomatoes %',axis=1,inplace=True) 원본을 바꾼다.

# %%
movies_str = pd.read_csv("korea_movie_list.csv",engine="python")
movies_str.columns
movies_str.shape
# Out:
# (2827, 14)

# %%
movies_str.head(2)
# Out:
#    movie_code    title         title_Eng  show_time  produce_year  open_date  \
# 0    20185801  할로우 차일드  The Hollow Child       88.0          2017   20180802
# 1    20187649  죽음의 리무진      Glass Coffin       75.0          2016   20180816
#
#   produce_state type nation       genre  director    actor show_type  \
# 0          개봉예정   장편    캐나다  공포(호러)/판타지    제레미 루터      NaN       NaN
# 1          개봉예정   장편    스페인  스릴러/공포(호러)  하리츠 쥬빌라가  파울라 본템피       NaN
#
#   watch_grade
# 0    15세이상관람가
# 1         NaN

# %%
movies_str_ser = movies_str['title']
movies_str_eng = movies_str['title_Eng']

# %%
movies_str_ser.hasnans
# Out:
# False

# %%
movies_str_eng.hasnans #누락값이 존재
# Out:
# True

# %%
movies_str_eng = movies_str_eng.dropna() #누락값을 삭제
movies_str_eng.shape
# Out:
# (2226,)

# %%
s=str('가을')
len(s)
s.find('가')
# Out:
# 0

# %%
movies_str_ser.str.find('할로우').head()#기존 파이썬 str함수도 사용 가능하다.
# Out:
# 0    0
# 1   -1
# 2   -1
# 3   -1
# 4   -1
# Name: title, dtype: int64

# %%
#pyqt=>gui프로그래밍.파이썬으로 배우는 알고리즘 트레이딩
